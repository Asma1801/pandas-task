# %% [markdown]
# <a href="https://colab.research.google.com/github/Asma1801/pandas-task/blob/main/Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df = pd.concat(
    map(pd.read_csv, ["/content/college_1.csv","/content/college_2.csv"]), ignore_index=True)
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
df1 = pd.read_csv("/content/college_1.csv")
data = df1[df1['CodeKata Score']>15000]
data.to_csv("Exceeded expectations.csv",index = False)
d = pd.read_csv("Exceeded expectations.csv")
d
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0

# %%
df2 = pd.read_csv("/content/college_2.csv")
data = df2[df2['CodeKata Score']>15000]
data.to_csv("Exceeded expectations.csv",index = False)
e = pd.read_csv("Exceeded expectations.csv")
e
# Out:
#             Name  python  python_en  mysql  computational_thinking  \
# 0  ASHOK KUMAR K     100          0     31                       9
#
#    Previous Geekions  CodeKata Score                              Department  \
# 0              19400           19400  Electronics and Electrical Engineering
#
#    Rising
# 0       0

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
score = df[df['CodeKata Score'].between(10000,15000)]
score.to_csv("Reached_expectations.csv",index = False)
a = pd.read_csv("Reached_expectations.csv")
a
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 0           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
score = df[df['CodeKata Score'].between(7000,10000)]
score.to_csv("Needs_improvement.csv",index = False)
a = pd.read_csv("Needs_improvement.csv")
a
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0              Sathammai.S   100.0    8.0               8980            8980
# 1             NIVEESHWAR S   100.0    0.0               8200            8200
# 2            KALAIARASAN K    85.0   47.0               7750            7880
# 3     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
score = df[df['CodeKata Score']<7000]
score.to_csv("Unsatisfactory.csv",index = False)
a = pd.read_csv("Unsatisfactory.csv")
a
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        J.SUGANTHI    27.0  50.00               5860            5860
# 1      thamizhpaana    29.0   0.00               5500            5500
# 2   Iyappan Samiraj    50.0  24.00               5400            5400
# 3      Ponniyamma.R   100.0  11.25               5380            5380
# 4         SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 88    praveen raj j    24.0   0.00               2380            2380
# 89       AMARNATH D    -1.0  12.00               1890            1890
# 90             bala    32.0   0.00               1720            1720
# 91             XY Z    -1.0  -1.00                  0               0
# 92        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
a =df['Previous Geekions'].mean()
b = df['CodeKata Score'].mean()
a,b
# Out:
# (3842.3529411764707, 4051.764705882353)

# %% [markdown]
# ###### No of students participated

# %%
df.dropna(inplace=True)
df['Name'].count()
# Out:
# 35

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df['python'].dropna().mean()
#df['mysql'].dropna().mean()
#df['python_en'].dropna().mean()
#df['computational_thinking'].dropna().mean()
# Out:
# 54.35294117647059

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
dff = df.sort_values(by=['CodeKata Score'],ascending = [False]).head(3)
dff
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.sort_values(by=['Previous Geekions'],ascending = [False]).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
data = pd.read_csv('/content/college_1.csv')
d = data.sort_values(by=['CodeKata Score'],ascending = [False]).head(1)
d
# Out:
#         Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0  A.Dharani    82.0   20.0              24500           24500
#
#                          Department  Rising
# 0  Computer Science and Engineering       0

# %%
data2 = pd.read_csv('/content/college_2.csv')
a = data2.sort_values(by=['CodeKata Score'],ascending = [False])
a=a.iloc[[0,3]]
a
# Out:
#               Name  python  python_en  mysql  computational_thinking  \
# 0    ASHOK KUMAR K     100          0     31                       9
# 3  Bodipudi Harini      -1          0     35                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 3              10040           10040
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 3  Electronics and Communication Engineering       0

# %%
f = [d,a]
r = pd.concat([a,d],ignore_index=True)
display(r)
# Out:
#               Name  python  python_en  mysql  computational_thinking  \
# 0    ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 1  Bodipudi Harini    -1.0        0.0   35.0                    -1.0
# 2        A.Dharani    82.0        NaN   20.0                     NaN
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              10040           10040
# 2              24500           24500
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1  Electronics and Communication Engineering       0
# 2           Computer Science and Engineering       0

# %%
import matplotlib.pyplot as plt
x = r['Department']
y = r['CodeKata Score']
fig = plt.figure(figsize=(15,8))
plt.bar(x,y,color='blue')
plt.title('Department wise toppers')
plt.xlabel("Department")
plt.ylabel("Codekata score")
plt.show()
